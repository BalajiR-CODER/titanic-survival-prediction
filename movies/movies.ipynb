# %%
import pandas as pd

# %%
df=pd.read_csv('Movies.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes',
#        'Netflix', 'Hulu', 'Prime Video', 'Disney+', 'Type', 'Directors',
#        'Genres', 'Country', 'Language', 'Runtime'],
#       dtype='object')

# %%
df
# Out:
#        Unnamed: 0     ID                           Title  Year  Age  IMDb  \
# 0               0      1                       Inception  2010  13+   8.8
# 1               1      2                      The Matrix  1999  18+   8.7
# 2               2      3          Avengers: Infinity War  2018  13+   8.5
# 3               3      4              Back to the Future  1985   7+   8.5
# 4               4      5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...           ...    ...                             ...   ...  ...   ...
# 16739       16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740       16740  16741                  The Poof Point  2001   7+   4.7
# 16741       16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742       16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743       16743  16744                In Beaver Valley  1950  NaN   NaN
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# ...

# %%
df.info()   #age,IMDB-1,Rotten tomatoes , Directors , Country , Language ,Runtime
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       16744 non-null  int64
#  1   ID               16744 non-null  int64
#  2   Title            16744 non-null  object
#  3   Year             16744 non-null  int64
#  4   Age              7354 non-null   object
#  5   IMDb             16173 non-null  float64
#  6   Rotten Tomatoes  5158 non-null   object
#  7   Netflix          16744 non-null  int64
#  8   Hulu             16744 non-null  int64
#  9   Prime Video      16744 non-null  int64
#  10  Disney+          16744 non-null  int64
#  11  Type             16744 non-null  int64
#  12  Directors        16018 non-null  object
#  13  Genres           16469 non-null  object
#  14  Country          16309 non-null  object
#  15  Language         16130 non-null  object
#  16  Runtime          16152 non-null  float64
# ...

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
a=df['Age'].mode()
im=df['IMDb'].mean()
rt=df['Rotten Tomatoes'].mode()
ct=df['Country'].mode()
DT=df['Directors'].mode()
lt=df['Language'].mode()
rt=df['Runtime'].mean()

# %%
df['Age']=df['Age'].fillna(a)
df['IMDb']=df['IMDb'].fillna(im)
df['Rotten Tomatoes']=df['Rotten Tomatoes'].fillna(rt)
df['Country']=df['Country'].fillna(ct)
df['Directors']=df['Directors'].fillna(DT)
df['Language']=df['Language'].fillna(lt)
df['Runtime']=df['Runtime'].fillna(rt)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       16744 non-null  int64
#  1   ID               16744 non-null  int64
#  2   Title            16744 non-null  object
#  3   Year             16744 non-null  int64
#  4   Age              7354 non-null   object
#  5   IMDb             16744 non-null  float64
#  6   Rotten Tomatoes  16744 non-null  object
#  7   Netflix          16744 non-null  int64
#  8   Hulu             16744 non-null  int64
#  9   Prime Video      16744 non-null  int64
#  10  Disney+          16744 non-null  int64
#  11  Type             16744 non-null  int64
#  12  Directors        16018 non-null  object
#  13  Genres           16469 non-null  object
#  14  Country          16309 non-null  object
#  15  Language         16130 non-null  object
#  16  Runtime          16744 non-null  float64
# ...

# %%
df=df.drop(columns=['Unnamed: 0'])

# %%
df['Rotten Tomatoes'] = df['Rotten Tomatoes'].str.rstrip('%').astype(float) / 10

df
# Out:
#           ID                           Title  Year  Age      IMDb  \
# 0          1                       Inception  2010  13+  8.800000
# 1          2                      The Matrix  1999  18+  8.700000
# 2          3          Avengers: Infinity War  2018  13+  8.500000
# 3          4              Back to the Future  1985   7+  8.500000
# 4          5  The Good, the Bad and the Ugly  1966  18+  8.800000
# ...      ...                             ...   ...  ...       ...
# 16739  16740       The Ghosts of Buxley Hall  1980  NaN  6.200000
# 16740  16741                  The Poof Point  2001   7+  4.700000
# 16741  16742           Sharks of Lost Island  2013  NaN  5.700000
# 16742  16743              Man Among Cheetahs  2017  NaN  6.600000
# 16743  16744                In Beaver Valley  1950  NaN  5.902751
#
#        Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0                  8.7        1     0            0        0     0
# ...

# %%
platform_df = pd.melt(df,id_vars=['Title','IMDb', 'Rotten Tomatoes'],value_vars=['Netflix','Hulu','Prime Video','Disney+']
        ,var_name='Platform',value_name='Availability')

# %%
platform_df = platform_df.loc[platform_df['Availability'] == 1]
platform_df
# Out:
#                                 Title      IMDb  Rotten Tomatoes Platform  \
# 0                           Inception  8.800000              8.7  Netflix
# 1                          The Matrix  8.700000              8.7  Netflix
# 2              Avengers: Infinity War  8.500000              8.4  Netflix
# 3                  Back to the Future  8.500000              9.6  Netflix
# 4      The Good, the Bad and the Ugly  8.800000              9.7  Netflix
# ...                               ...       ...              ...      ...
# 66971       The Ghosts of Buxley Hall  6.200000              NaN  Disney+
# 66972                  The Poof Point  4.700000              NaN  Disney+
# 66973           Sharks of Lost Island  5.700000              NaN  Disney+
# 66974              Man Among Cheetahs  6.600000              NaN  Disney+
# 66975                In Beaver Valley  5.902751              NaN  Disney+
#
#        Availability
# 0                 1
# 1                 1
# ...

# %% [markdown]
# # Data Analysis

# %% [markdown]
# 1. find the no of movies available in the dataset

# %%
df.shape[0]
# Out:
# 16744

# %% [markdown]
# 2. find the total movies casted in Netflix

# %%
df['Netflix'].sum()

df.loc[df['Netflix'] == 1, 'Netflix'].count()

df.loc[df['Netflix'] == 1].shape[0]
# Out:
# 3560

# %%
df['tot_plts']=df[['Netflix', 'Hulu', 'Prime Video', 'Disney+']].sum(axis=1)
df
# Out:
#           ID                           Title  Year  Age      IMDb  \
# 0          1                       Inception  2010  13+  8.800000
# 1          2                      The Matrix  1999  18+  8.700000
# 2          3          Avengers: Infinity War  2018  13+  8.500000
# 3          4              Back to the Future  1985   7+  8.500000
# 4          5  The Good, the Bad and the Ugly  1966  18+  8.800000
# ...      ...                             ...   ...  ...       ...
# 16739  16740       The Ghosts of Buxley Hall  1980  NaN  6.200000
# 16740  16741                  The Poof Point  2001   7+  4.700000
# 16741  16742           Sharks of Lost Island  2013  NaN  5.700000
# 16742  16743              Man Among Cheetahs  2017  NaN  6.600000
# 16743  16744                In Beaver Valley  1950  NaN  5.902751
#
#        Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0                  8.7        1     0            0        0     0
# ...

# %% [markdown]
# get the platform wise no of movies

# %%
df[['Netflix', 'Hulu', 'Prime Video', 'Disney+']].sum()

platform_df.value_counts('Platform')
platform_df['Platform'].value_counts()
# Out:
# Platform
# Prime Video    12354
# Netflix         3560
# Hulu             903
# Disney+          564
# Name: count, dtype: int64

# %% [markdown]
# get the plt wise highest imdb and rotten tomatoes

# %%
platform_df.groupby('Platform').agg({'IMDb': 'mean', 'Rotten Tomatoes': 'mean'}).round(1)
# Out:
#              IMDb  Rotten Tomatoes
# Platform
# Disney+       6.4              6.4
# Hulu          6.1              6.7
# Netflix       6.2              6.6
# Prime Video   5.8              6.4
